# %% [markdown]
# # 数理統計学(2019)　課題2
#
# ### このnotebookには、いくつかの設問が記載されています。
# ### 先頭から順番に、指示に従ってPython Codeをcellに記述してください。
# ### codeを記述するcellは、各自適切に生成してください。
#
# ## 課題提出方法
# ### 各自のGitHubに、学籍番号_MS2（たとえば、C180001_MS2）という名称のrepositoryを作成してください。
# ### このnotebookを各自のGitHubのリポジトリ（学籍番号_MS2)へコピーしてください。
# ### このnotebookに記載されたcodeがデータファイルを参照している場合、そのデータファイルも必ずGitHubのリポジトリへコピーしてください。
# ### 各自のGitHubのリポジトリをoffice 365のメールアカウントを使用して、sugimura@ccg.ac.jpへ送信してください。メールの件名は、学籍番号_MS2としてください。
# ### 【重要】指定された方法で課題を提出することも課題に含まれています。

# %% [markdown]
# ## 事前学習
# ### 課題に取り組む前に以下の事項を読んでください。
#
#
# ### データの種類
# #### 代表的なデータの種類について説明します。
#
# ##### 数値データ
# 数値データは、定量データの測定に用いられます。-------身長、株価など
#
# 数値データには、離散データと連続データとがあります。
# + 離散データ-------ショッピングサイトで顧客が購買した商品の個数、SNSにおける「いいね！」の回数
# + 連続データ-------ログインからログアウトまでの時間、一日の降水量
#
# ##### カテゴリデータ
# カテゴリデータは、Yes/No、住所地、業種など、数学的な意味を持たないデータです。
#
# ##### 順序データ
# 順序データは、数値データとカテゴリデータとの中間的なデータです。
#
# 数学的な意味を持つカテゴリデータと言うことができます。
#
# たとえば、映画やレストランの5段階評価：1，2，3，4，5などは順序データです。評価の値1、2、3、4、5は数学的な意味を持っています。
#
#
# ### 平均値、中央値、モード、標準偏差
#
# #### 数値データの特徴を表す指標として、平均値、中央値、モード、標準偏差などが用いられます。これらは、最も基本的な統計量です。
#
# #### 平均値
# ##### 平均値は、合計値／サンプル数　によって計算することができます。
#
#
# 実際に、平均値（期待値と呼ぶこともある）を計算しよう。
#
#
# $$ \mu = \frac{1}{N} \sum_{i=1}^{N} x_i $$
#
#
# 平均値muを計算するためには、合計sum_scoreとサンプルの個数（サンプルサイズ）Nとを用います。
#
# mu = sum_score / N
#
#
# #### 中央値
# ##### 中央値は、値をソートして（昇順または降順に並べる）、中央の値を選びます。
# 例：
#
# 最初のデータ　　：0，2，3，2，1，0，0，2，0
#
# ソート後のデータ：0，0，0, 0，1，2，2，2，3
#
# 中央値：小さい方から5番目の値である1が中央値です。
#
# なお、サンプル数が偶数であるとき、中央にある2つの値の平均を中央値とします。
#
# #### モード
# ##### モードは、データセット(data set)において出現頻度が最も高い値です。
# 連続数値データの場合、モードを決めることはできません。
#
# たとえば、
#
# データセット：0, 2, 3, 2, 1, 0, 0, 2, 0
#
# におけるモードは、0です。
#
#
# #### 標準偏差 ####
#
# 標準偏差は、分散の平方根である。分散は、元のデータが2乗された次元(dimension)をもっているので、そのままでは、データを扱い難いです。そこで、分散の平方根である標準偏差が使われます。標準偏差の計算式は以下の通りです。
#
# $$ \sigma = \sqrt{\sigma^2} = \sqrt{\frac{1}{N-1}\sum_{i=1}^N (x_i - \mu)^2}  $$

# %% [markdown]
# ### 【設問のための準備】
#
# #### Pythonにおいて数値計算を行うためのモジュルnumpyをインポートし、numpy数値計算ライブラリを利用できるように設定した後、
# #### numpyのメソッドnumpy.random.normal(60, 15, 50)を実行して、平均=60、標準偏差=15、個数=50である乱数からなるリストを発生させ、
# #### データファイル data_a1.csv に出力しました。
# #### 実際には、numpy.random.normalによって発生されるデータは、numpy.ndarray型ですが、リスト型に変換した後にファイルに保存しました。
# #### このデータは、リスト型データdata_a1に読み込まれています。
# #### さらに、このリスト型データdata_a1のいくつかの要素を書き換えたリスト型データdata_a2も準備しました。
# #### 以下では、これらのリスト型データdata_a1とリスト型データdata_a2に関して、設問に解答してください。

# %%
#必要なライブラリをインポートします。最初に、このセルを必ず実行してください。

import numpy as np
import csv

# %%
#　ファイル data_a1.csv からデータを読み出して、リスト型データ data_a1　に保存します。このセルを実行してください。
with open('data_a1.csv') as f1:
    reader = csv.reader(f1)
    for row in reader:
        data_a1 = row
f1.close()

# %%
#　ファイル data_a2.csv からデータを読み出して、リスト型データ data_a2　に保存します。このセルを実行してください。
with open('data_a2.csv') as f2:
    reader = csv.reader(f2)
    for row in reader:
        data_a2 = row
f2.close()

# %% [markdown]
# ### 準備完了です。では、設問に解答してください。

# %% [markdown]
# ## 【設問1】
# ### リスト型データdata_a1の要素は文字列型です。そこで、文字列のリストをfloat型数値のリストdata_b1に変換してください。
#
# #### ヒント：文字列sは、float(s)によってfloat型数値に変換できます。

# %%
data_b1 = [float(s) for s in data_a1]
data_b1
# Out:
# [63.335060537432405,
#  61.19683813953228,
#  43.15066971466772,
#  48.5825383481092,
#  70.91977263852039,
#  50.355096592653204,
#  57.404661835250685,
#  54.214114666958686,
#  65.23005472923558,
#  97.49675117979585,
#  40.42116884341342,
#  48.88447638031949,
#  39.65379476104175,
#  51.06660234693088,
#  51.080777531336636,
#  20.356529408593868,
#  40.25031785883687,
#  52.24503318236681,
#  44.501547909454025,
#  39.75438700025401,
#  41.03442147844019,
#  57.04609386786059,
#  47.053953766419944,
#  46.07141192484974,
#  63.80976065742252,
#  37.41822737052139,
#  54.64637050822946,
#  41.25382356098915,
#  52.495094239874845,
#  60.3952646507607,
#  77.35068951149204,
#  21.11693966528115,
#  18.864202636173232,
#  61.19495520282264,
#  62.91276635396384,
#  48.56582847722918,
#  55.9726922340421,
#  64.34312380024582,
#  40.05580255949208,
#  60.74552486361691,
#  88.92019999073332,
#  42.594437927847906,
#  72.82330313927326,
#  44.872155033304665,
#  27.55302433845527,
#  48.515546193186715,
#  69.02494088803385,
#  49.273483348158,
#  51.73608521218283,
#  43.41327572778414,
#  33.428125101507646,
#  82.28922630077136,
#  45.112635830413616,
#  34.64832952584918,
#  32.69595963349294,
#  46.60731566722406,
#  62.14412491729404,
#  40.73331155373117,
#  36.28825973738665,
#  33.79855585706839,
#  45.80973267464007,
#  38.845829666168854,
#  30.486131988362736,
#  15.658450232490068,
#  51.447996010121265,
#  45.200381843566944,
#  49.646922204491894,
#  47.034512625863314,
#  46.45265718257247,
#  23.497718391717292,
#  50.12575723294531,
#  59.53422048798225,
#  49.65751664367125,
#  48.011526424384634,
#  33.09885151662978,
#  74.89684841028719,
#  46.6834786307227,
#  77.07584716204187,
#  54.50120583659287,
#  38.49170883088148,
#  34.09340647771049,
#  54.61565576065983,
#  26.947817871234236,
#  43.71873403851359,
#  66.0279677286638,
#  38.01416027417275,
#  29.055576311373148,
#  31.806926956301883,
#  65.81012850395027,
#  63.23635872532947,
#  46.08258451318225,
#  42.192355994667736,
#  31.772436195973086,
#  57.250261644435845,
#  26.242218233275626,
#  56.532688408340654,
#  49.07419299300505,
#  69.46442155276226,
#  39.624041053367414,
#  65.71407443550505,
#  32.87238737754514,
#  60.18270132725347,
#  42.27029343766773,
#  39.833582164538335,
#  46.85945687650262,
#  69.52632125396497,
#  43.001749119027274,
#  52.18217933300447,
#  41.15119532542912,
#  49.164214138619904,
#  36.09809995678155,
#  36.614115048723384,
#  73.54758408272568,
#  74.52814865846088,
#  55.845257034786464,
#  48.83734921632409,
#  58.405239764301655,
#  64.38594892357243,
#  71.92645870626731,
#  70.35990152075536,
#  29.46137913791621,
#  62.6218934134421,
#  29.139787499798317,
#  58.528711462112796,
#  68.1473255147958,
#  48.30289591890194,
#  58.6276383665027,
#  50.654326497529205,
#  48.28421787658736,
#  56.28792205813605,
#  43.15403217144856,
#  48.26982609371632,
#  75.00138942545053,
#  54.90754405366583,
#  52.994552157615594,
#  57.562937797666876,
#  53.6860939116069,
#  57.95384829816293,
#  62.94825646615932,
#  50.866250059717714,
#  57.13781672522702,
#  49.09954467357785,
#  31.87017208576386,
#  70.61480065312657,
#  56.666620033600424,
#  62.907010977452636,
#  50.77561999084062,
#  31.246346723425997,
#  71.05873896739142,
#  53.111418231708186,
#  47.31589655649617,
#  69.51663084915543,
#  53.929760709656115,
#  61.392181494403076,
#  36.54127182673831,
#  23.925484110398486,
#  45.756988710454266,
#  44.01046327126012,
#  25.751537503431447,
#  57.1242402356008,
#  39.740186654686056,
#  50.65103042941391,
#  47.25133985906283,
#  52.090908194209106,
#  37.73320584837966,
#  55.53120215062506,
#  65.83421518047118,
#  45.821184785224496,
#  34.06691848694167,
#  60.19439864586974,
#  33.35538140056242,
#  52.82431566361777,
#  43.63638618513692,
#  56.8580967503895,
#  38.230545447749485,
#  23.035590212767623,
#  58.16830790726836,
#  40.34521544290819,
#  55.22365477263222,
#  48.0022587034981,
#  47.5708665388326,
#  62.76060472662404,
#  67.50712742573985,
#  55.63347248343522,
#  46.41048376184331,
#  50.80085139105827,
#  54.85199740975314,
#  44.847222879139075,
#  49.33143300219606,
#  53.95284063846839,
#  31.87196721471519,
#  58.37820119991621,
#  58.29728157358408,
#  58.19315922439939,
#  37.12007081662078,
#  90.64919367096299,
#  64.12077306557316,
#  38.24823838688304,
#  44.08079393823375,
#  42.3910445477938,
#  47.79689074375599,
#  25.204899853227868,
#  36.14693787816262,
#  48.984200542763986,
#  65.01500119233708,
#  56.49018963737979,
#  46.04776305409365,
#  55.00533239574856,
#  47.7264713176484,
#  32.172976454065775,
#  41.640010490786956,
#  40.86985654293591,
#  63.03490126295027,
#  35.417633293020145,
#  44.33552216038193,
#  37.81368588861106,
#  40.09981355577386,
#  64.04767501225045,
#  28.23284837935701,
#  49.31915727914547,
#  29.68633215140602,
#  48.824068106078954,
#  55.55342475819722,
#  64.74568275445685,
#  26.163752108498812,
#  37.30300538815471,
#  65.27803766512511,
#  75.90694508789659,
#  55.53522986666183,
#  58.83843262449997,
#  72.99852988601361,
#  42.52602063839953,
#  30.823412565412287,
#  59.53544489744354,
#  56.47778368469353,
#  31.89641951763731,
#  63.46416828786791,
#  49.177077321422956,
#  45.540020186201886,
#  59.18702670663508,
#  87.73281131235811,
#  19.406482963574284,
#  43.21273782044552,
#  71.53331611283795,
#  33.634714023041546,
#  18.752577801121745,
#  40.2211581686297,
#  34.09990683787567,
#  80.43629470573677,
#  47.61877260830264,
#  27.12091150498773,
#  54.599009510235206,
#  70.95557901215517,
#  39.26915791405482,
#  44.49169283894222,
#  81.99434225645697,
#  22.677008471314124,
#  75.32670476114538,
#  63.45687530504785,
#  72.98643024315905,
#  52.610565499525585,
#  64.71288381955517,
#  36.860231041430026,
#  43.45389672854765,
#  60.84878594211028,
#  65.58299759216527,
#  42.7826756265067,
#  50.16245600709119,
#  59.23667440768574,
#  38.234437307899725,
#  45.22708541403875,
#  48.514044977389695,
#  78.8871306442142,
#  27.432177657303818,
#  56.49221510964154,
#  55.9479249627099,
#  59.48534060864324,
#  41.56044777333584,
#  24.052239203044667,
#  59.716342406838145,
#  62.3281456044744,
#  52.0047554215352,
#  55.94699064735033,
#  72.21652038861201,
#  42.29851608939743,
#  59.45089843860211,
#  52.222145084863605,
#  54.77460425202077,
#  43.499606062194836,
#  64.8889277128105,
#  74.39164887987485,
#  63.001900693885155,
#  45.72649855102832,
#  48.9643164621415,
#  28.657581707660608,
#  48.456916000101664,
#  49.25996321857449,
#  77.16087051398722,
#  69.59752368025626,
#  61.93584432451623,
#  49.81159897222336,
#  36.54426857127923,
#  60.5468178763561,
#  43.46824460199474,
#  52.92137008045576,
#  87.30847892040113,
#  59.52052465296146,
#  46.121297167800996,
#  60.453172284169355,
#  53.60437497947204,
#  63.75962383928546,
#  16.498444827099483,
#  62.9801968519781,
#  39.7863573597859,
#  68.26221195773832,
#  50.2837045251248,
#  41.11058698226336,
#  66.09673644713742,
#  40.64341647775787,
#  59.2820685856516,
#  64.57106312185894,
#  68.0794352637048,
#  37.06494130843617,
#  39.97709955107685,
#  45.455865387241346,
#  59.757481407579256,
#  37.31151215282628,
#  83.94147736011843,
#  42.5864503208684,
#  52.31812751477831,
#  59.423170065421644,
#  38.20529926288904,
#  46.354583838275104,
#  50.72221790004658,
#  49.98037106595137,
#  70.53640368617219,
#  58.41176798784802,
#  94.47837518966209,
#  54.83618758106643,
#  45.983459768932626,
#  55.15506228708231,
#  40.433152300303206,
#  28.37080671000365,
#  45.332414269634995,
#  38.243789454426505,
#  29.595702656525873,
#  58.12340773488607,
#  45.047541706786774,
#  57.03923171596285,
#  36.203744936669665,
#  62.46534637847843,
#  49.64549585339646,
#  51.50967479766076,
#  80.2504399448604,
#  40.692765265129694,
#  54.163144018511474,
#  50.883406182659854,
#  46.7948791329584,
#  47.82788472070226,
#  25.31035904899525,
#  63.94732412240104,
#  61.982065416283056,
#  23.74945009155713,
#  41.899293672359526,
#  60.806675841588245,
#  59.20923873230063,
#  72.051937053074,
#  40.29303970248246,
#  31.951792907659843,
#  45.114511146209665,
#  37.36402207422795,
#  85.3288374125924,
#  40.0795718640978,
#  36.99554870185799,
#  40.010343070346046,
#  55.872625785719414,
#  34.45845689323255,
#  60.196186199707505,
#  70.59255984599227,
#  50.762976701266226,
#  45.98408851524858,
#  48.46234385704015,
#  66.39582082389964,
#  60.1585945167966,
#  20.297004050043565,
#  82.14286240380913,
#  47.53112901082344,
#  47.695716413188705,
#  63.49663866061819,
#  31.254667461408488,
#  33.18402504629567,
#  54.021739681765304,
#  80.03054405265947,
#  53.525770991836204,
#  30.07523306992285,
#  65.07625881448307,
#  53.10746579663848,
#  50.47889795783871,
#  45.287256058826074,
#  50.98473549503892,
#  39.45540345376212,
#  46.19024498660689,
#  53.92671382101061,
#  62.982911190796415,
#  53.59998358649528,
#  44.9657206916254,
#  69.93291222431614,
#  56.152417249817496,
#  56.550473943527116,
#  30.568651800694703,
#  35.802499684151186,
#  72.58956993555795,
#  39.772311159649384,
#  40.0311583202251,
#  37.47956758577298,
#  32.139189670518164,
#  53.714712971564786,
#  48.69387531647363,
#  38.97540924286907,
#  69.58928280263433,
#  44.138023119586975,
#  59.08431933440832,
#  47.82616702783068,
#  23.039689465675004,
#  70.40308096074133,
#  57.51798947664131,
#  48.10586114858838,
#  43.20017323934078,
#  61.71666814775643,
#  48.35332872160975,
#  55.50062866323172,
#  26.379062410782414,
#  47.577450630008656,
#  69.67113353145824,
#  54.591217660550015,
#  43.48203260962593,
#  68.37177112882438,
#  47.203638070113065,
#  47.16974690851939,
#  35.19583532549568,
#  45.55184704203295,
#  60.8977471751598,
#  46.7514967869142,
#  47.911187144251855,
#  46.740638691788654,
#  33.85973265092234,
#  41.05732834749176,
#  57.02090017841293,
#  30.406085605127156,
#  40.8923369691141,
#  62.706757317848606,
#  50.99544525790138,
#  85.77310863309184,
#  27.030957668668673,
#  32.76574734134084,
#  40.26135572470315,
#  66.30056013710401,
#  29.16376258864922,
#  48.06988381284416,
#  30.91305582838845,
#  14.399543698559143,
#  54.30673065142561,
#  52.13700689383001,
#  38.2292730600817,
#  41.79427068833385,
#  58.038517516484106,
#  50.37323555623571,
#  44.968143471057225,
#  46.31735260077858,
#  37.962918158421566,
#  46.16131409783803,
#  54.55869248992335,
#  58.684268180779895,
#  32.62058949534048,
#  18.00936427924032,
#  45.19022472576871,
#  46.990503661881704,
#  34.698137851483054,
#  45.42531250225218,
#  32.314096688114546,
#  24.878724362648498,
#  46.979884120476285,
#  37.42967809866607,
#  35.145419543243676,
#  63.099890968567514,
#  66.07637586339679,
#  52.07760001930014,
#  13.857831573398883,
#  45.486464046282805,
#  52.93557288743802,
#  54.0783709064418,
#  67.26106850002559,
#  46.71430365986149,
#  38.79182210529775,
#  34.82975131688778,
#  44.103048943410386,
#  52.54811328103184,
#  24.589375390498535,
#  37.11163561801988,
#  71.51161089620672,
#  75.15978778211294,
#  34.481872341538086,
#  48.725181292947,
#  34.33919792830478,
#  64.51250885782241,
#  33.4523980460154,
#  45.33837284087459,
#  75.41855817263745,
#  59.85575834391229,
#  83.94928627749783,
#  64.07491987112805,
#  61.785937592767155,
#  59.32168375817546,
#  35.76470646697486,
#  62.76071467239242,
#  27.29219441126274,
#  39.07309152036765,
#  63.17238105772855,
#  43.56408663373896,
#  53.54950790964302,
#  32.900848222541185,
#  45.0196297088266,
#  41.28694820400408,
#  63.949913232721656,
#  36.50450722794437,
#  41.20758323602999,
#  55.183725819970405,
#  68.04543434928397,
#  28.56385081586594,
#  44.5996685068404,
#  74.9063562196191,
#  45.710522231799914,
#  58.89441586838124,
#  54.26596287632505,
#  50.326396444085674,
#  39.86221444660791,
#  44.372547572197746,
#  32.97897408035372,
#  68.45629478589113,
#  70.74230259618871,
#  59.01991212368947,
#  47.82482581845479,
#  40.39567109816444,
#  27.48428724728807,
#  38.58608347648713,
#  57.66136822840144,
#  28.221380207933382,
#  26.654043122781456,
#  52.03724551579126,
#  54.39685468262382,
#  63.61896845355109,
#  37.459671193320816,
#  39.984065575794446,
#  26.091595718104628,
#  62.35248476680918,
#  30.07864709824363,
#  39.122319505579696,
#  10.179394726371235,
#  47.56941210371825,
#  39.25681554243346,
#  22.90769227538975,
#  30.775676337957247,
#  49.92410179339548,
#  36.70723146134629,
#  39.216149315885986,
#  32.442015281880884,
#  72.00375871369008,
#  51.4113581193795,
#  42.63308178609198,
#  42.485723637112784,
#  68.30503619449775,
#  68.42926638454495,
#  31.700397193362264,
#  34.429306785953266,
#  57.071012114676535,
#  42.407334321131174,
#  57.73927223812499,
#  51.905787080737085,
#  58.901044445158384,
#  35.109696606551935,
#  56.20061055216738,
#  35.304713188354405,
#  46.98113850129942,
#  48.09716372026049,
#  64.63350447010396,
#  62.58724048068916,
#  49.39824096662076,
#  44.72366157025409,
#  70.82988195993973,
#  74.97824921618603,
#  60.581097837024075,
#  56.90081322324581,
#  46.075646918864166,
#  55.17252183553028,
#  43.72789075610049,
#  37.923032378749795,
#  49.62593474530165,
#  68.95753439810579,
#  44.25307337352115,
#  42.85485982136814,
#  48.02023295045817,
#  63.61007354535966,
#  48.16646643716746,
#  41.90856142941762,
#  63.33000857772602,
#  32.24726805849225,
#  56.23319452616511,
#  46.463903811709976,
#  48.608495537471065,
#  55.56836267746279,
#  40.08932913918842,
#  56.51126485379547,
#  34.21865904930714,
#  25.173582547181407,
#  79.58785024502824,
#  79.02568920837827,
#  59.56562644076449,
#  27.81800221077426,
#  61.229490852464274,
#  56.86061770494422,
#  64.56461828725989,
#  29.836929960183124,
#  53.37044984139773,
#  40.22340308354668,
#  58.579704733167304,
#  61.782870725496565,
#  39.61169021985886,
#  44.54535162412367,
#  52.817756092014534,
#  49.44296709957773,
#  48.68307744353689,
#  65.03266857327226,
#  58.10381367822839,
#  61.223606250852974,
#  43.76167110980238,
#  45.43651539117885,
#  58.65670070660032,
#  26.62635686105424,
#  42.9921233613896,
#  38.84116378162226,
#  32.820849755325156,
#  46.74985459913718,
#  70.02216620453319,
#  49.787896193386715,
#  45.94208122274659,
#  75.26037718121569,
#  4.295074843881622,
#  69.64241166555621,
#  52.66796106400817,
#  39.190768683201675,
#  59.95604633552431,
#  10.802580999945128,
#  53.18333939685153,
#  24.68324745387054,
#  43.955691218306164,
#  65.09040338212057,
#  31.892333138506682,
#  30.4785620683392,
#  59.714136092545786,
#  63.94453797835344,
#  26.92234805372231,
#  47.3325678205571,
#  62.00488186040259,
#  50.9652997354482,
#  44.71894031597867,
#  41.50879871785783,
#  32.55679955706158,
#  35.746021574405276,
#  29.363870199448325,
#  60.59541792983607,
#  60.18965467222862,
#  66.82104855783308,
#  67.79023597257968,
#  24.956270459638247,
#  37.500839955626056,
#  35.1938221954735,
#  42.11070882325617,
#  54.11629673692821,
#  66.84545669356663,
#  14.973638458786965,
#  34.13727834781602,
#  56.35012415352881,
#  60.68912147701321,
#  50.822834467893365,
#  31.132392239389034,
#  33.69239869480703,
#  66.00423240842044,
#  46.51656164512507,
#  68.34713802634715,
#  76.34222820555038,
#  58.24302582241477,
#  57.813715274692534,
#  39.668849458843695,
#  50.840807651855684,
#  48.78417419229022,
#  45.88212639941187,
#  34.91056546659848,
#  46.85600194584935,
#  67.96899454763324,
#  42.0629584124343,
#  33.01231909698993,
#  68.79694365284519,
#  38.10944288531669,
#  61.505658125448804,
#  50.36911999588703,
#  40.60967606785337,
#  41.12281304134803,
#  44.7010492888443,
#  58.81425892800363,
#  55.014029067585376,
#  61.36370146171365,
#  61.966909141536306,
#  26.240164209061316,
#  18.6715682951455,
#  41.05675377439739,
#  61.37810009768106,
#  22.371357805398958,
#  46.872722838237515,
#  79.25752872268433,
#  64.2614860042469,
#  55.87720682257601,
#  23.949672009355414,
#  36.636716746618795,
#  44.879559858463516,
#  64.86160876210981,
#  65.02155007455784,
#  25.22408178877331,
#  62.002749307697115,
#  58.613549905207705,
#  61.44077992753125,
#  40.44760907084287,
#  64.82870012021972,
#  8.84686159699298,
#  31.754121576687538,
#  62.44088074939226,
#  33.8439081011904,
#  54.54967840609806,
#  64.6902736532038,
#  55.31922347715111,
#  48.77558149012992,
#  37.282925747621235,
#  60.49509330981757,
#  25.859175505915747,
#  58.62118267817523,
#  45.41266749327468,
#  61.33615397217447,
#  55.87273981430787,
#  29.58007120523394,
#  61.46732086088198,
#  19.827170026895274,
#  31.7525475415786,
#  72.76905833640316,
#  43.03004908239072,
#  32.52491224584313,
#  61.59695885824908,
#  53.01591604643627,
#  36.554320257639965,
#  55.97396479310787,
#  46.906991593353865,
#  61.47125922164709,
#  55.19094534404742,
#  71.41083046956464,
#  46.68097983845006,
#  31.366830555503032,
#  53.50788476871078,
#  59.337450574373385,
#  41.126483919327214,
#  60.56113237268203,
#  42.866480296471266,
#  41.003177300892006,
#  40.18603113483174,
#  87.11699744883622,
#  47.267449436711544,
#  44.990341680801016,
#  34.84223150246444,
#  61.13956167415698,
#  58.51231200969754,
#  46.65640828097833,
#  51.77979336558282,
#  30.315114740246567,
#  68.86287218183584,
#  37.33149749350831,
#  44.9094887615625,
#  24.81774918983892,
#  45.231939025813325,
#  43.987092922999736,
#  70.3777585871053,
#  27.973839104200906,
#  63.538984836280875,
#  69.42380206331359,
#  70.13630391773577,
#  38.19467970009728,
#  42.65745885590648,
#  41.76703050925658,
#  43.0756552758217,
#  35.96227704399951,
#  42.00157885980415,
#  64.63501381022662,
#  49.42305882385014,
#  57.52926938545838,
#  53.05985906254487,
#  47.27137654021394,
#  74.0825094263216,
#  59.52476561548311,
#  60.694673398498594,
#  37.10982150078166,
#  53.80422257629758,
#  25.577010897395866,
#  61.02085002706766,
#  24.9774182718589,
#  54.276785881592666,
#  48.38245071771413,
#  60.25777450480586,
#  58.37533779191935,
#  34.37835441866926,
#  29.24273465883157,
#  54.61639386174748,
#  45.12368056139248,
#  52.907363390623175,
#  49.8425748976909,
#  17.99915867352739,
#  39.63704762938461,
#  65.67158498823781,
#  45.62487224353641,
#  78.1928411371233,
#  52.07225644750621,
#  60.402537847938504,
#  32.92989703625945,
#  58.31987072471707,
#  33.87527028605066,
#  33.97994665689646,
#  58.80896758677489,
#  23.01772950321042,
#  49.2376266310273,
#  55.651095862472474,
#  31.857121449446474,
#  57.059279288844095,
#  37.698116572460975,
#  56.425835931256245,
#  64.16705692773576,
#  37.36812316219376,
#  66.04747334811228,
#  54.612893494248766,
#  43.64002554709791,
#  47.952152360707416,
#  50.91037197067033,
#  58.276164068181934,
#  50.86643072842884,
#  22.6206357731183,
#  49.601176825264794,
#  41.49618176062795,
#  24.475690122762327,
#  49.461778480585615,
#  35.925982416584404,
#  54.327406795898234,
#  42.150821902698745,
#  38.12526123044465,
#  30.167600969490927,
#  49.014126039081226,
#  91.3724864310027,
#  43.077710475616506,
#  37.0371009091703,
#  52.302893988766634,
#  56.111832589737915,
#  59.863002178823876,
#  76.04029306189139,
#  39.870444560983486,
#  41.48212007796547,
#  24.975697874397138,
#  32.25602889187828,
#  63.45787514472697,
#  34.559271727687,
#  50.1876050081812,
#  76.84585978181553,
#  31.22140611229094,
#  27.671290851644383,
#  39.42454343299495,
#  15.40444660340816,
#  48.27420752218007,
#  43.05952175456958,
#  54.06452027818804,
#  43.49253358493699,
#  62.74622770226797,
#  34.93998803658745,
#  66.31141775039961,
#  51.38644457270866,
#  39.197205638070976,
#  60.0899889395741,
#  56.902401666218296,
#  62.36078403217465,
#  65.36123144971236,
#  49.894484906901525,
#  36.79578727438553,
#  59.642438346859635,
#  55.003809479669385,
#  69.18136272887817,
#  53.22168002975706,
#  51.928689098673274,
#  34.67395991917948,
#  38.59049581540771,
#  28.682417956910008,
#  36.02510541454069,
#  50.97916729114051,
#  55.978777191729705,
#  37.73737593441082,
#  58.02755967845395,
#  49.23055757619181,
#  51.74616550510527,
#  46.62640534712514,
#  36.18867680337317,
#  72.61102540164461,
#  61.36507859596614,
#  56.89372409858666,
#  27.555303818696007,
#  55.66125231092538,
#  70.1391637779931,
#  65.69057033487758,
#  50.809504774167856,
#  23.009590056977075,
#  76.44603685521096,
#  43.1684826356125,
#  44.48677557624872,
#  54.2053481422569,
#  39.45349603779303,
#  47.05441411232145,
#  43.53832829297322,
#  28.349312926647524,
#  41.8252432095919,
#  61.042719772120215,
#  47.95810531142544,
#  40.470492302143256,
#  56.03253241448665,
#  29.26578491464131,
#  43.228893168729925,
#  35.6332215259054,
#  50.4067493049792,
#  37.26005648153713,
#  21.783667172802986,
#  55.3206274852147,
#  39.868720032703145,
#  68.72895464378843,
#  52.70145715623821,
#  64.38058237578599,
#  51.79188929837158,
#  63.3326623437922,
#  61.44752062623376,
#  50.31607892860545,
#  79.18271976699205,
#  43.92158181706079,
#  50.57364852058306,
#  28.012693443481403,
#  47.38682987002358,
#  33.000563050069566,
#  60.081582193669846,
#  39.13445835602748,
#  44.96363752006841,
#  48.37474184633929,
#  57.617112720664934,
#  64.3518655553952,
#  53.62667981746106,
#  102.32119228674021,
#  63.68597822194512,
#  42.9002040372028,
#  55.26521903843921,
#  54.7492902930759,
#  80.377355663382,
#  41.18599179667859,
#  39.922717375234214,
#  58.0010078966927,
#  45.5823383372435,
#  29.027254115889892,
#  77.20782913861686,
#  50.69693683702637,
#  77.41841612787839,
#  34.27086181755031,
#  50.559673024737656,
#  70.07597900847745,
#  45.2487694538501,
#  59.76486409062099,
#  64.50425643258575,
#  44.37162363435545,
#  54.293301685438706,
#  37.62347482365122,
#  85.97836389168442,
#  61.53400143949463,
#  50.1281457530197,
#  49.47164617359379,
#  40.03302183233888,
#  28.569866108646416,
#  50.133544202389835,
#  46.29471070305381,
#  53.59431082474216,
#  38.849548774779564,
#  56.773162557289766,
#  56.83283832128813,
#  36.59912758419434,
#  53.07177327949639,
#  43.394584337427915,
#  49.94897148844993,
#  45.08729406868771]

# %% [markdown]
# ## 【設問2】
# ### float型のリストdata_b1をint型のリストdata_c1に変換してください。
# #### float型データxは、int(x)によってint型数値に変換できます。

# %%
data_c1 = [int (x) for x in data_b1]
data_c1
# Out:
# [63,
#  61,
#  43,
#  48,
#  70,
#  50,
#  57,
#  54,
#  65,
#  97,
#  40,
#  48,
#  39,
#  51,
#  51,
#  20,
#  40,
#  52,
#  44,
#  39,
#  41,
#  57,
#  47,
#  46,
#  63,
#  37,
#  54,
#  41,
#  52,
#  60,
#  77,
#  21,
#  18,
#  61,
#  62,
#  48,
#  55,
#  64,
#  40,
#  60,
#  88,
#  42,
#  72,
#  44,
#  27,
#  48,
#  69,
#  49,
#  51,
#  43,
#  33,
#  82,
#  45,
#  34,
#  32,
#  46,
#  62,
#  40,
#  36,
#  33,
#  45,
#  38,
#  30,
#  15,
#  51,
#  45,
#  49,
#  47,
#  46,
#  23,
#  50,
#  59,
#  49,
#  48,
#  33,
#  74,
#  46,
#  77,
#  54,
#  38,
#  34,
#  54,
#  26,
#  43,
#  66,
#  38,
#  29,
#  31,
#  65,
#  63,
#  46,
#  42,
#  31,
#  57,
#  26,
#  56,
#  49,
#  69,
#  39,
#  65,
#  32,
#  60,
#  42,
#  39,
#  46,
#  69,
#  43,
#  52,
#  41,
#  49,
#  36,
#  36,
#  73,
#  74,
#  55,
#  48,
#  58,
#  64,
#  71,
#  70,
#  29,
#  62,
#  29,
#  58,
#  68,
#  48,
#  58,
#  50,
#  48,
#  56,
#  43,
#  48,
#  75,
#  54,
#  52,
#  57,
#  53,
#  57,
#  62,
#  50,
#  57,
#  49,
#  31,
#  70,
#  56,
#  62,
#  50,
#  31,
#  71,
#  53,
#  47,
#  69,
#  53,
#  61,
#  36,
#  23,
#  45,
#  44,
#  25,
#  57,
#  39,
#  50,
#  47,
#  52,
#  37,
#  55,
#  65,
#  45,
#  34,
#  60,
#  33,
#  52,
#  43,
#  56,
#  38,
#  23,
#  58,
#  40,
#  55,
#  48,
#  47,
#  62,
#  67,
#  55,
#  46,
#  50,
#  54,
#  44,
#  49,
#  53,
#  31,
#  58,
#  58,
#  58,
#  37,
#  90,
#  64,
#  38,
#  44,
#  42,
#  47,
#  25,
#  36,
#  48,
#  65,
#  56,
#  46,
#  55,
#  47,
#  32,
#  41,
#  40,
#  63,
#  35,
#  44,
#  37,
#  40,
#  64,
#  28,
#  49,
#  29,
#  48,
#  55,
#  64,
#  26,
#  37,
#  65,
#  75,
#  55,
#  58,
#  72,
#  42,
#  30,
#  59,
#  56,
#  31,
#  63,
#  49,
#  45,
#  59,
#  87,
#  19,
#  43,
#  71,
#  33,
#  18,
#  40,
#  34,
#  80,
#  47,
#  27,
#  54,
#  70,
#  39,
#  44,
#  81,
#  22,
#  75,
#  63,
#  72,
#  52,
#  64,
#  36,
#  43,
#  60,
#  65,
#  42,
#  50,
#  59,
#  38,
#  45,
#  48,
#  78,
#  27,
#  56,
#  55,
#  59,
#  41,
#  24,
#  59,
#  62,
#  52,
#  55,
#  72,
#  42,
#  59,
#  52,
#  54,
#  43,
#  64,
#  74,
#  63,
#  45,
#  48,
#  28,
#  48,
#  49,
#  77,
#  69,
#  61,
#  49,
#  36,
#  60,
#  43,
#  52,
#  87,
#  59,
#  46,
#  60,
#  53,
#  63,
#  16,
#  62,
#  39,
#  68,
#  50,
#  41,
#  66,
#  40,
#  59,
#  64,
#  68,
#  37,
#  39,
#  45,
#  59,
#  37,
#  83,
#  42,
#  52,
#  59,
#  38,
#  46,
#  50,
#  49,
#  70,
#  58,
#  94,
#  54,
#  45,
#  55,
#  40,
#  28,
#  45,
#  38,
#  29,
#  58,
#  45,
#  57,
#  36,
#  62,
#  49,
#  51,
#  80,
#  40,
#  54,
#  50,
#  46,
#  47,
#  25,
#  63,
#  61,
#  23,
#  41,
#  60,
#  59,
#  72,
#  40,
#  31,
#  45,
#  37,
#  85,
#  40,
#  36,
#  40,
#  55,
#  34,
#  60,
#  70,
#  50,
#  45,
#  48,
#  66,
#  60,
#  20,
#  82,
#  47,
#  47,
#  63,
#  31,
#  33,
#  54,
#  80,
#  53,
#  30,
#  65,
#  53,
#  50,
#  45,
#  50,
#  39,
#  46,
#  53,
#  62,
#  53,
#  44,
#  69,
#  56,
#  56,
#  30,
#  35,
#  72,
#  39,
#  40,
#  37,
#  32,
#  53,
#  48,
#  38,
#  69,
#  44,
#  59,
#  47,
#  23,
#  70,
#  57,
#  48,
#  43,
#  61,
#  48,
#  55,
#  26,
#  47,
#  69,
#  54,
#  43,
#  68,
#  47,
#  47,
#  35,
#  45,
#  60,
#  46,
#  47,
#  46,
#  33,
#  41,
#  57,
#  30,
#  40,
#  62,
#  50,
#  85,
#  27,
#  32,
#  40,
#  66,
#  29,
#  48,
#  30,
#  14,
#  54,
#  52,
#  38,
#  41,
#  58,
#  50,
#  44,
#  46,
#  37,
#  46,
#  54,
#  58,
#  32,
#  18,
#  45,
#  46,
#  34,
#  45,
#  32,
#  24,
#  46,
#  37,
#  35,
#  63,
#  66,
#  52,
#  13,
#  45,
#  52,
#  54,
#  67,
#  46,
#  38,
#  34,
#  44,
#  52,
#  24,
#  37,
#  71,
#  75,
#  34,
#  48,
#  34,
#  64,
#  33,
#  45,
#  75,
#  59,
#  83,
#  64,
#  61,
#  59,
#  35,
#  62,
#  27,
#  39,
#  63,
#  43,
#  53,
#  32,
#  45,
#  41,
#  63,
#  36,
#  41,
#  55,
#  68,
#  28,
#  44,
#  74,
#  45,
#  58,
#  54,
#  50,
#  39,
#  44,
#  32,
#  68,
#  70,
#  59,
#  47,
#  40,
#  27,
#  38,
#  57,
#  28,
#  26,
#  52,
#  54,
#  63,
#  37,
#  39,
#  26,
#  62,
#  30,
#  39,
#  10,
#  47,
#  39,
#  22,
#  30,
#  49,
#  36,
#  39,
#  32,
#  72,
#  51,
#  42,
#  42,
#  68,
#  68,
#  31,
#  34,
#  57,
#  42,
#  57,
#  51,
#  58,
#  35,
#  56,
#  35,
#  46,
#  48,
#  64,
#  62,
#  49,
#  44,
#  70,
#  74,
#  60,
#  56,
#  46,
#  55,
#  43,
#  37,
#  49,
#  68,
#  44,
#  42,
#  48,
#  63,
#  48,
#  41,
#  63,
#  32,
#  56,
#  46,
#  48,
#  55,
#  40,
#  56,
#  34,
#  25,
#  79,
#  79,
#  59,
#  27,
#  61,
#  56,
#  64,
#  29,
#  53,
#  40,
#  58,
#  61,
#  39,
#  44,
#  52,
#  49,
#  48,
#  65,
#  58,
#  61,
#  43,
#  45,
#  58,
#  26,
#  42,
#  38,
#  32,
#  46,
#  70,
#  49,
#  45,
#  75,
#  4,
#  69,
#  52,
#  39,
#  59,
#  10,
#  53,
#  24,
#  43,
#  65,
#  31,
#  30,
#  59,
#  63,
#  26,
#  47,
#  62,
#  50,
#  44,
#  41,
#  32,
#  35,
#  29,
#  60,
#  60,
#  66,
#  67,
#  24,
#  37,
#  35,
#  42,
#  54,
#  66,
#  14,
#  34,
#  56,
#  60,
#  50,
#  31,
#  33,
#  66,
#  46,
#  68,
#  76,
#  58,
#  57,
#  39,
#  50,
#  48,
#  45,
#  34,
#  46,
#  67,
#  42,
#  33,
#  68,
#  38,
#  61,
#  50,
#  40,
#  41,
#  44,
#  58,
#  55,
#  61,
#  61,
#  26,
#  18,
#  41,
#  61,
#  22,
#  46,
#  79,
#  64,
#  55,
#  23,
#  36,
#  44,
#  64,
#  65,
#  25,
#  62,
#  58,
#  61,
#  40,
#  64,
#  8,
#  31,
#  62,
#  33,
#  54,
#  64,
#  55,
#  48,
#  37,
#  60,
#  25,
#  58,
#  45,
#  61,
#  55,
#  29,
#  61,
#  19,
#  31,
#  72,
#  43,
#  32,
#  61,
#  53,
#  36,
#  55,
#  46,
#  61,
#  55,
#  71,
#  46,
#  31,
#  53,
#  59,
#  41,
#  60,
#  42,
#  41,
#  40,
#  87,
#  47,
#  44,
#  34,
#  61,
#  58,
#  46,
#  51,
#  30,
#  68,
#  37,
#  44,
#  24,
#  45,
#  43,
#  70,
#  27,
#  63,
#  69,
#  70,
#  38,
#  42,
#  41,
#  43,
#  35,
#  42,
#  64,
#  49,
#  57,
#  53,
#  47,
#  74,
#  59,
#  60,
#  37,
#  53,
#  25,
#  61,
#  24,
#  54,
#  48,
#  60,
#  58,
#  34,
#  29,
#  54,
#  45,
#  52,
#  49,
#  17,
#  39,
#  65,
#  45,
#  78,
#  52,
#  60,
#  32,
#  58,
#  33,
#  33,
#  58,
#  23,
#  49,
#  55,
#  31,
#  57,
#  37,
#  56,
#  64,
#  37,
#  66,
#  54,
#  43,
#  47,
#  50,
#  58,
#  50,
#  22,
#  49,
#  41,
#  24,
#  49,
#  35,
#  54,
#  42,
#  38,
#  30,
#  49,
#  91,
#  43,
#  37,
#  52,
#  56,
#  59,
#  76,
#  39,
#  41,
#  24,
#  32,
#  63,
#  34,
#  50,
#  76,
#  31,
#  27,
#  39,
#  15,
#  48,
#  43,
#  54,
#  43,
#  62,
#  34,
#  66,
#  51,
#  39,
#  60,
#  56,
#  62,
#  65,
#  49,
#  36,
#  59,
#  55,
#  69,
#  53,
#  51,
#  34,
#  38,
#  28,
#  36,
#  50,
#  55,
#  37,
#  58,
#  49,
#  51,
#  46,
#  36,
#  72,
#  61,
#  56,
#  27,
#  55,
#  70,
#  65,
#  50,
#  23,
#  76,
#  43,
#  44,
#  54,
#  39,
#  47,
#  43,
#  28,
#  41,
#  61,
#  47,
#  40,
#  56,
#  29,
#  43,
#  35,
#  50,
#  37,
#  21,
#  55,
#  39,
#  68,
#  52,
#  64,
#  51,
#  63,
#  61,
#  50,
#  79,
#  43,
#  50,
#  28,
#  47,
#  33,
#  60,
#  39,
#  44,
#  48,
#  57,
#  64,
#  53,
#  102,
#  63,
#  42,
#  55,
#  54,
#  80,
#  41,
#  39,
#  58,
#  45,
#  29,
#  77,
#  50,
#  77,
#  34,
#  50,
#  70,
#  45,
#  59,
#  64,
#  44,
#  54,
#  37,
#  85,
#  61,
#  50,
#  49,
#  40,
#  28,
#  50,
#  46,
#  53,
#  38,
#  56,
#  56,
#  36,
#  53,
#  43,
#  49,
#  45]

# %% [markdown]
# ## 【設問3】
# ### 設問1、設問2と同様に、文字列型のリストdata_a2をint型のリストdata_c2に変換してください。
# #### ヒント：リスト内包表記を用いると、1行のコードで変換を実現できます。

# %%
data_c2 = [int(float(s)) for s in data_a2]
print(data_c2)
# Out:
# [63, 61, 43, 48, 70, 50, 57, 54, 65, 97, 40, 48, 39, 51, 51, 20, 40, 52, 44, 39, 41, 57, 47, 46, 63, 37, 54, 41, 52, 60, 77, 21, 18, 61, 62, 48, 55, 64, 40, 60, 88, 42, 72, 44, 27, 48, 69, 49, 51, 43, 33, 82, 45, 34, 32, 46, 62, 40, 36, 33, 45, 38, 30, 15, 51, 45, 49, 47, 46, 23, 50, 59, 49, 48, 33, 74, 46, 77, 54, 38, 34, 54, 26, 43, 66, 38, 29, 31, 65, 63, 46, 42, 31, 57, 26, 56, 49, 69, 39, 65, 32, 60, 42, 39, 46, 69, 43, 52, 41, 49, 36, 36, 73, 74, 55, 48, 58, 64, 71, 70, 29, 62, 29, 58, 68, 48, 58, 50, 48, 56, 43, 48, 75, 54, 52, 57, 53, 57, 62, 50, 57, 49, 31, 70, 56, 62, 50, 31, 71, 53, 47, 69, 53, 61, 36, 23, 45, 44, 25, 57, 39, 50, 47, 52, 37, 55, 65, 45, 34, 60, 33, 52, 43, 56, 38, 23, 58, 40, 55, 48, 47, 62, 67, 55, 46, 50, 54, 44, 49, 53, 31, 58, 58, 58, 37, 90, 64, 38, 44, 42, 47, 25, 36, 48, 65, 56, 46, 55, 47, 32, 41, 40, 63, 35, 44, 37, 40, 64, 28, 49, 29, 48, 55, 64, 26, 37, 65, 75, 55, 58, 72, 42, 30, 59, 56, 31, 63, 49, 45, 59, 87, 19, 43, 71, 33, 18, 40, 34, 80, 47, 27, 54, 70, 39, 44, 81, 22, 75, 63, 72, 52, 64, 36, 43, 60, 65, 42, 50, 59, 38, 45, 48, 78, 27, 56, 55, 59, 41, 24, 59, 62, 52, 55, 72, 42, 59, 52, 54, 43, 64, 74, 63, 45, 48, 28, 48, 49, 77, 69, 61, 10000, 36, 60, 43, 52, 87, 59, 46, 60, 53, 63, 16, 62, 39, 68, 50, 41, 66, 40, 59, 64, 68, 37, 39, 45, 59, 37, 83, 42, 52, 59, 38, 46, 50, 49, 70, 58, 94, 54, 45, 55, 40, 28, 45, 38, 29, 58, 45, 57, 36, 62, 49, 51, 80, 40, 54, 50, 46, 47, 25, 63, 61, 23, 41, 60, 59, 72, 40, 31, 45, 37, 85, 40, 36, 40, 55, 34, 60, 70, 50, 45, 48, 66, 60, 20, 82, 47, 47, 63, 31, 33, 54, 80, 53, 30, 65, 53, 50, 45, 50, 39, 46, 53, 62, 53, 44, 69, 56, 56, 30, 35, 72, 39, 40, 37, 32, 53, 48, 38, 69, 44, 59, 47, 23, 70, 57, 48, 43, 61, 48, 55, 26, 47, 69, 54, 43, 68, 47, 47, 35, 45, 60, 46, 47, 46, 33, 41, 57, 30, 40, 62, 50, 85, 27, 32, 40, 66, 29, 48, 30, 14, 54, 52, 38, 41, 58, 50, 44, 46, 37, 46, 54, 58, 32, 18, 45, 46, 34, 45, 32, 24, 46, 37, 35, 63, 66, 52, 13, 45, 52, 54, 67, 46, 38, 34, 44, 52, 24, 37, 71, 75, 34, 48, 34, 64, 33, 45, 75, 59, 83, 64, 61, 59, 35, 62, 27, 39, 63, 43, 53, 32, 45, 41, 63, 36, 41, 55, 68, 28, 44, 74, 45, 58, 54, 50, 39, 44, 32, 68, 70, 59, 47, 40, 27, 38, 57, 28, 26, 52, 54, 63, 37, 39, 26, 62, 30, 39, 10, 47, 39, 22, 30, 49, 36, 39, 32, 72, 51, 42, 42, 68, 68, 31, 34, 57, 42, 57, 51, 58, 35, 56, 35, 46, 48, 64, 62, 49, 44, 70, 74, 60, 56, 46, 55, 43, 37, 49, 68, 44, 42, 20000, 63, 48, 41, 63, 32, 56, 46, 48, 55, 40, 56, 34, 25, 79, 79, 59, 27, 61, 56, 64, 29, 53, 40, 58, 61, 39, 44, 52, 49, 48, 65, 58, 61, 43, 45, 58, 26, 42, 38, 32, 46, 70, 49, 45, 75, 4, 69, 52, 39, 59, 10, 53, 24, 43, 65, 31, 30, 59, 63, 26, 47, 62, 50, 44, 41, 32, 35, 29, 60, 60, 66, 67, 24, 37, 35, 42, 54, 66, 14, 34, 56, 60, 50, 31, 33, 66, 46, 68, 76, 58, 57, 39, 50, 48, 45, 34, 46, 67, 42, 33, 68, 38, 61, 50, 40, 41, 44, 58, 55, 61, 61, 26, 18, 41, 61, 22, 46, 79, 64, 55, 23, 36, 44, 64, 65, 25, 62, 58, 61, 40, 64, 8, 31, 62, 33, 54, 64, 55, 48, 37, 60, 25, 58, 45, 61, 55, 29, 61, 19, 31, 72, 43, 32, 61, 53, 36, 55, 46, 61, 55, 71, 46, 31, 53, 59, 41, 60, 42, 41, 40, 87, 47, 44, 34, 61, 58, 46, 51, 30, 68, 37, 44, 24, 45, 43, 70, 27, 63, 69, 70, 38, 42, 41, 43, 35, 42, 64, 49, 57, 53, 47, 74, 59, 60, 37, 53, 25, 61, 24, 54, 48, 60, 58, 34, 29, 54, 45, 52, 49, 17, 39, 65, 45, 78, 52, 60, 32, 58, 33, 33, 58, 23, 49, 55, 31, 57, 37, 56, 64, 37, 66, 54, 43, 47, 50, 58, 50, 22, 49, 41, 24, 49, 35, 54, 42, 38, 30, 49, 91, 43, 37, 52, 56, 59, 76, 39, 41, 24, 32, 63, 34, 50, 76, 31, 27, 39, 15, 48, 43, 54, 43, 62, 34, 66, 51, 39, 60, 56, 62, 65, 49, 36, 59, 55, 69, 53, 51, 34, 38, 28, 36, 50, 55, 37, 58, 49, 51, 46, 36, 72, 61, 56, 27, 55, 70, 65, 50, 23, 76, 43, 44, 54, 39, 47, 43, 28, 41, 61, 47, 40, 56, 29, 43, 35, 50, 37, 21, 55, 39, 68, 52, 64, 51, 63, 61, 50, 79, 43, 50, 28, 47, 33, 60, 39, 44, 48, 57, 64, 53, 102, 63, 42, 55, 54, 80, 41, 39, 58, 45, 29, 77, 50, 77, 34, 50, 70, 45, 59, 64, 44, 54, 37, 85, 61, 50, 49, 40, 28, 50, 46, 53, 38, 56, 56, 36, 53, 43, 49 ...

# %% [markdown]
# ## 【設問4】
# #### 整数型のリストdata_c1の平均値を上記計算式を使って計算してください。

# %%
avg_1 = sum(data_c1)/len(data_c1)

# %% [markdown]
# ## statisticsモジュール
# ### Pythonのstatisticsモジュールを用いると、リスト型データの平均、中央値、標準偏差などを計算することができます。
# ### 準備のためstatisticsモジュールから必要なライブラリをインポートします。

# %%
#　このセルを必ず実行してください。
from statistics import mean, median, stdev

# %% [markdown]
# ## 【設問5】
# #### statisticsモジュールを使って整数型リストdata_c1の平均、中央値、標準偏差を求めてください。

# %%
from statistics import mean

lst = [43.0, 7.654999999999999] 
mea = mean(lst) 
print(mea)
# Out:
# 25.3275

# %% [markdown]
# ## 【設問6】
# #### statisticsモジュールを使って整数型リストdata_c2の平均、中央値、標準偏差を求めてください。

# %% [markdown]
# ## 【準備】
# ### データdata_c1は、正規分布にしたがったデータです。データdata_c1のヒストグラムを表示します。

# %%
#グラフを描画するためのモジュールをインポートします
import matplotlib.pyplot as plt
#Jupyter Notebookにグラフを表示するための命令です
# %matplotlib inline

plt.hist(data_c1, 25)
plt.show()

# %% [markdown]
# ### データdata_c1は、平均からわずかに大きい値の出現頻度が少ないようですが、全体的には、平均を中心として左右になだらかな勾配を持つ正規分布の特徴を示しています。
#
# ### 次に、データdata_c2について調べましょう。data_c2は、data_c1の中の2つの要素の値を変更することによって得られたデータです。
# ### 設問6でわかったように、data_c1とdata_c2とを比べると、中央値はほとんど同じ値ですが、平均と標準偏差が大きく異なります。
# ### data_c1とdata_c2の要素の個数は、1000個です。そのうち、2個の要素の値を変えると、平均値が大幅に変化したことになります。
# ### では、data_c2は、data_c1の2個の要素の値をどのように変化させたのでしょう。
# ### その原因を突き止めましょう。

# %% [markdown]
# ## 【設問7】
# ### data_c1のヒストグラムと同様に、data_c2のヒストグラムを表示させてください。

# %% [markdown]
# ### 上のヒストグラムからどんなことがわかりますか？
# ### ヒストグラムの横軸の値（データの値）が0から20,000まで広がっています。
# ### しかし、値の度数（出現頻度）を表す縦軸は、左端（およそ0から800の範囲）に集中しています。
# ### ここからわかることは、出現頻度は少ないけれど、極端に大きな値（異常値）を持つ要素が存在することです。

# %% [markdown]
# ## 【設問8】
# ### データdata_c2から異常値（外れ値と呼ぶこともあります）を除去したデータdata_c3を作成してください。
# #### ヒント： データセットの中央値からある値以上離れている要素を除去することにより、外れ値を除去することができます。
# #### ある値として、標準偏差の2倍を用いてください。
# #### 得られたデータdata_c3の要素の個数を表示してください。

# %% [markdown]
# ## 【設問9】
# ### 得られたデータdata_c3のヒストグラムを表示してください。

# %% [markdown]
# ## 【設問10】
# ### 得られたデータdata_c3の平均、中央値、標準偏差を求めてください。
